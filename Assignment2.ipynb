# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv("/content/StudentsPerformanceTest1(1).csv")
df1
# Out:
#    gender math score reading score  writing score  Placement Score  \
# 0  female         72            72           74.0             78.0
# 1  female         69            90           88.0              NaN
# 2  female         90            95           93.0             74.0
# 3    male         47            57            NaN             78.0
# 4    male         na            78           75.0             81.0
# 5  female         71            Na           78.0             70.0
# 6    male         12            44           52.0             12.0
# 7    male        NaN            65           67.0             49.0
# 8    male          5            77           89.0             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2      na
# 2                      2  Nashik
# 3                      1      Na
# 4                      3    Pune
# 5                      4      na
# 6                      2  Nashik
# ...

# %%
df1.isnull
# Out:
# <bound method DataFrame.isnull of    gender math score reading score  writing score  Placement Score  \
# 0  female         72            72           74.0             78.0
# 1  female         69            90           88.0              NaN
# 2  female         90            95           93.0             74.0
# 3    male         47            57            NaN             78.0
# 4    male         na            78           75.0             81.0
# 5  female         71            Na           78.0             70.0
# 6    male         12            44           52.0             12.0
# 7    male        NaN            65           67.0             49.0
# 8    male          5            77           89.0             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2      na
# 2                      2  Nashik
# 3                      1      Na
# 4                      3    Pune
# 5                      4      na
# ...

# %%
series = pd.isnull(df1["math score"])
df1[series]
# Out:
#   gender math score reading score  writing score  Placement Score  \
# 7   male        NaN            65           67.0             49.0
#
#    placement offer count Region
# 7                      1   Pune

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df1['gender'] = le.fit_transform(df1['gender'])
newdf=df1
df1
# Out:
#    gender math score reading score  writing score  Placement Score  \
# 0       0         72            72           74.0             78.0
# 1       0         69            90           88.0              NaN
# 2       0         90            95           93.0             74.0
# 3       1         47            57            NaN             78.0
# 4       1         na            78           75.0             81.0
# 5       0         71            Na           78.0             70.0
# 6       1         12            44           52.0             12.0
# 7       1        NaN            65           67.0             49.0
# 8       1          5            77           89.0             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2      na
# 2                      2  Nashik
# 3                      1      Na
# 4                      3    Pune
# 5                      4      na
# 6                      2  Nashik
# ...

# %%
missing_values = ["Na", "na"]
df1= pd.read_csv("/content/StudentsPerformanceTest1(1).csv", na_values =
missing_values)
df1
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0  female        72.0           72.0           74.0             78.0
# 1  female        69.0           90.0           88.0              NaN
# 2  female        90.0           95.0           93.0             74.0
# 3    male        47.0           57.0            NaN             78.0
# 4    male         NaN           78.0           75.0             81.0
# 5  female        71.0            NaN           78.0             70.0
# 6    male        12.0           44.0           52.0             12.0
# 7    male         NaN           65.0           67.0             49.0
# 8    male         5.0           77.0           89.0             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2     NaN
# 2                      2  Nashik
# 3                      1     NaN
# 4                      3    Pune
# 5                      4     NaN
# 6                      2  Nashik
# ...

# %%
ndf=df1
ndf.fillna(0)
# Out:
#    gender  math score  reading score  writing score  Placement Score  \
# 0  female        72.0           72.0           74.0             78.0
# 1  female        69.0           90.0           88.0              0.0
# 2  female        90.0           95.0           93.0             74.0
# 3    male        47.0           57.0            0.0             78.0
# 4    male         0.0           78.0           75.0             81.0
# 5  female        71.0            0.0           78.0             70.0
# 6    male        12.0           44.0           52.0             12.0
# 7    male         0.0           65.0           67.0             49.0
# 8    male         5.0           77.0           89.0             55.0
#
#    placement offer count  Region
# 0                      1    Pune
# 1                      2       0
# 2                      2  Nashik
# 3                      1       0
# 4                      3    Pune
# 5                      4       0
# 6                      2  Nashik
# ...

# %%
mean_val=df1['math score'].mean()
df1['math score'].fillna(value = mean_val , inplace= True)
df1
# Out:
# <ipython-input-17-0adb267b8289>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['math score'].fillna(value = mean_val , inplace= True)
#    gender  math score  reading score  writing score  Placement Score  \
# 0  female   72.000000           72.0           74.0             78.0
# 1  female   69.000000           90.0           88.0              NaN
# 2  female   90.000000           95.0           93.0             74.0
# 3    male   47.000000           57.0            NaN             78.0
# ...

# %%
median_val=df1['reading score'].median()
df1['reading score'].fillna(value = median_val, inplace=True)
df1
# Out:
# <ipython-input-19-023def6aafdd>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['reading score'].fillna(value = median_val, inplace=True)
#    gender  math score  reading score  writing score  Placement Score  \
# 0  female   72.000000           72.0           74.0             78.0
# 1  female   69.000000           90.0           88.0              NaN
# 2  female   90.000000           95.0           93.0             74.0
# 3    male   47.000000           57.0            NaN             78.0
# ...

# %%
sd_v=df1['Placement Score'].std()
df1['Placement Score'].fillna(value=sd_v,inplace=True)
df1
# Out:
# <ipython-input-21-89c5e0b9344f>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['Placement Score'].fillna(value=sd_v,inplace=True)
#    gender  math score  reading score  writing score  Placement Score  \
# 0  female   72.000000           72.0           74.0        78.000000
# 1  female   69.000000           90.0           88.0        23.295846
# 2  female   90.000000           95.0           93.0        74.000000
# 3    male   47.000000           57.0            NaN        78.000000
# ...

# %%
min_v=df1['writing score'].std()
df1['writing score'].fillna(value=sd_v,inplace=True)
df1
# Out:
# <ipython-input-22-29d2bdef0604>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['writing score'].fillna(value=sd_v,inplace=True)
#    gender  math score  reading score  writing score  Placement Score  \
# 0  female   72.000000           72.0      74.000000        78.000000
# 1  female   69.000000           90.0      88.000000        23.295846
# 2  female   90.000000           95.0      93.000000        74.000000
# 3    male   47.000000           57.0      25.345255        78.000000
# ...

# %%
df=pd.read_csv("/content/demo1.csv")
df
# Out:
#     math score  reading score  writing score  placement score  \
# 0           80             68             70               89
# 1           71             61             85               91
# 2           79             16             87               77
# 3           61             77             74               76
# 4           78             71             67               90
# 5           73             68             90               80
# 6           77             62             70               35
# 7           74             45             80               12
# 8           76             60             79               77
# 9           75             65             85               87
# 10         160             67             12               83
# 11          79             72             88              180
# 12          80             80             78               94
# 13          78             69             71               90
# ...

# %%
import seaborn as sns

# %%
col = ['math score', 'reading score', 'writing score', 'placement score']
df.boxplot(col)
# Out:
# <Axes: >

# %%
import numpy as np
from scipy import stats

# %%
z = np.abs(stats.zscore(df['math score']))
z
# Out:
# 0     0.175646
# 1     0.528288
# 2     0.214828
# 3     0.920112
# 4     0.254010
# 5     0.449923
# 6     0.293193
# 7     0.410740
# 8     0.332375
# 9     0.371558
# 10    2.958952
# 11    0.214828
# 12    0.175646
# 13    0.254010
# 14    0.371558
# 15    0.254010
# 16    0.059449
# 17    0.175646
# 18    0.371558
# 19    0.097281
# 20    0.606653
# 21    0.608004
# 22    0.489105
# 23    0.410740
# 24    0.371558
# 25    3.742601
# 26    0.489105
# 27    0.528288
# 28    1.391653
# Name: math score, dtype: float64

# %%
threshold = 0.18
sample_outliers = np.where(z <threshold)
sample_outliers
# Out:
# (array([ 0, 12, 16, 17, 19]),)

# %%
print(np.where(df['math score']>90))
# Out:
# (array([10, 21, 25, 28]),)

# %%
df=pd.read_csv("/content/demo1.csv")
df_stud=df
ninetieth_percentile = np.percentile(df_stud['math score'], 80)
b = np.where(df_stud['math score']>ninetieth_percentile,
ninetieth_percentile, df_stud['math score'])
print("New array:",b)
# Out:
# New array: [80.  71.  79.  61.  78.  73.  77.  74.  76.  75.  80.8 79.  80.  78.
#  75.  78.  80.8 80.  75.  80.8 69.  80.8 72.  74.  75.  80.8 72.  71.
#  80.8]

# %%
df_stud.insert(1,"m score",b,True)
df_stud
# Out:
#     math score  m score  reading score  writing score  placement score  \
# 0           80     80.0             68             70               89
# 1           71     71.0             61             85               91
# 2           79     79.0             16             87               77
# 3           61     61.0             77             74               76
# 4           78     78.0             71             67               90
# 5           73     73.0             68             90               80
# 6           77     77.0             62             70               35
# 7           74     74.0             45             80               12
# 8           76     76.0             60             79               77
# 9           75     75.0             65             85               87
# 10         160     80.8             67             12               83
# 11          79     79.0             72             88              180
# ...

# %%
df2=pd.read_csv("/content/Mall_Customers.csv")
df2
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]
